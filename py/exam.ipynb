# %%
name = ["홍길동", "이순신", "슈퍼맨", "배트맨", "박서방"]
age = [22, 33, 34, 12, 54]

print(dict([(n, a) for n, a in zip(name, age)]))
# Out:
# {'홍길동': 22, '이순신': 33, '슈퍼맨': 34, '배트맨': 12, '박서방': 54}

# %%
students = [('jane', 22, "A"), ("dave", 32, "B"), ("sally", 17, "B")]

name, age, grade = [[s[i] for s in students] for i in range(3)]
print(name, age, grade, sep="\n")
# Out:
# ['jane', 'dave', 'sally']
# [22, 32, 17]
# ['A', 'B', 'B']

# %%
for s in students:
    student_dict = dict(zip(title, s))
    print(student_dict)
