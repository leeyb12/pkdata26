# %% [markdown]
# ## 음악 차트 크롤링 모음

# %%
# 멜론 차트 Top 100 크롤링
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.melon.com/chart/index.htm"
headers = {"user-agent":"Mozilla/5.0 (Window NT 10.0: Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0"}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html.parser')

title = soup.select('.rank01')[:100]
name = soup.select('.rank02 > span')[:100]
str = ''
for i, (t, n) in enumerate(zip(title, name), 1):
    str += f'{i}위 = {t.text.strip()} : {n.text.strip()}\n'

print(str)

# %%
# 벅스 차트 크롤링
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://music.bugs.co.kr/chart/track/realtime/total?wl_ref=M_contents_03_01"
headers = {"user-agent":"Mozilla/5.0 (Window NT 10.0: Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0"}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html.parser')

title2 = soup.select('p.title > a')[:100]
name2 = soup.select('p.artist > a:nth-of-type(1)')[:100]
str2 = ''
for i2, (t2, n2) in enumerate(zip(title2, name2), 1):
    str2 += f'{i2}위 = {t2.text.strip()} : {n2.text.strip()}\n'

print(str2)

# %%
# 지니 뮤직 차트(Top200) 크롤링 (1 ~ 50위)
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.genie.co.kr/chart/top200"
headers = {"user-agent":"Mozilla/5.0 (Window NT 10.0: Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0"}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html.parser')

title3 = soup.select('td.info > a:nth-of-type(1)')[:50]
name3 = soup.select('td.info > a:nth-of-type(2)')[:50]
str3 = ''
for k, (t3, n3) in enumerate(zip(title3, name3), 1):
    str3 += f'{k}위 = {t3.text.strip()} : {n3.text.strip()}\n'

print(str3)

# %%
# 지니 뮤직 차트(Top200) 크롤링 (51 ~ 100위)
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.genie.co.kr/chart/top200?ditc=D&ymd=20260224&hh=10&rtm=Y&pg=2"
headers = {"user-agent":"Mozilla/5.0 (Window NT 10.0: Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0"}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html.parser')

title3 = soup.select('td.info > a:nth-of-type(1)')[:50]
name3 = soup.select('td.info > a:nth-of-type(2)')[:50]
str3 = ''
for k, (t3, n3) in enumerate(zip(title3, name3), 51):
    str3 += f'{k}위: {t3.text.strip()} : {n3.text.strip()}\n'

print(str3)

# %%
# 지니 뮤직 차트(Top200) 크롤링 (101 ~ 150위)
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.genie.co.kr/chart/top200?ditc=D&ymd=20260224&hh=10&rtm=Y&pg=3"
headers = {"user-agent":"Mozilla/5.0 (Window NT 10.0: Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0"}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html.parser')

title3 = soup.select('td.info > a:nth-of-type(1)')[:50]
name3 = soup.select('td.info > a:nth-of-type(2)')[:50]
str3 = ''
for k, (t3, n3) in enumerate(zip(title3, name3), 101):
    str3 += f'{k}위: {t3.text.strip()} : {n3.text.strip()}\n'

print(str3)

# %%
# 지니 뮤직 차트(Top200) 크롤링 (151 ~ 200위)
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.genie.co.kr/chart/top200?ditc=D&ymd=20260224&hh=10&rtm=Y&pg=3"
headers = {"user-agent":"Mozilla/5.0 (Window NT 10.0: Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0"}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html.parser')

title3 = soup.select('td.info > a:nth-of-type(1)')[:50]
name3 = soup.select('td.info > a:nth-of-type(2)')[:50]
str3 = ''
for k, (t3, n3) in enumerate(zip(title3, name3), 151):
    str3 += f'{k}위: {t3.text.strip()} : {n3.text.strip()}\n'

print(str3)

# %%
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.pusan.ac.kr/kor/CMS/MenuMgr/menuListOnBuilding.do?mCode=MN202"
headers = {"user-agent":"Mozilla/5.0 (Window NT 10.0: Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0"}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html.parser')
menulist = soup.select('.menu-tbl')
menu = soup.select('h3.menu-tit01 + p')
won = soup.select('.menu-tit01')
day = soup.select('.day')
date = soup.select('.date')
for d, dd, w, m in zip(day, date, won, menu):
    print('=' * 15)
    print(d.text.strip(), dd.text.strip())
    print('-' * 15)
    print(w.text + '\n' + m.text.replace('\r', '\n'))
# Out:
# ...
# 월 2026.02.23
# ---------------
# 정식-5,500원
# 백미밥
# 반계탕
# 탕수육/레몬소스
# 사각어묵오징어무침
# 잔멸치건새우견과류볶음
# 다시마무채무침
# 포기김치
#
# ...
# 화 2026.02.24
# ---------------
# 정식-5,500원
# 녹차밥
# 수제비국
# 돈육김치볶음
# 새우가스/케찹
# 푸실리과일샐러드
# 상추겉절이
# 석박지
#
# ...
# 수 2026.02.25
# ---------------
# 정식-5,500원
# 백미밥
# 짬뽕국
# 떡갈비/파채소스
# 스파게티/로제소스
# 어묵버섯조림
# 치커리유자청무침
# 배추김치
#
# ...
# 목 2026.02.26
# ---------------
# 정식-5,500원
# 흑미밥
# 어묵국
# 치킨치즈가스/머스터드
# 쇠고기하이라이스
# 순대볶음
# 해초무초무침
# 배추김치
#
# ...
# 금 2026.02.27
# ---------------
# 정식-5,500원
# 백미밥
# 닭개장
# 돈육바삭불고기
# 우동야채볶음
# 볶음김치/온두부
# 콩나물무침
# 석박지
