# %% [markdown]
# # 응용

# %%
# 응용 

import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.melon.com/chart/index.htm"
headers = {"user-agent":"Mozilla/5.0 (Window NT 10.0: Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0"}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html.parser')

title = soup.select('.rank01')[:100]
name = soup.select('.rank02 > span')[:100]
album = soup.select('.rank03 > a')[:100]
str = ''
for i, (t, n, a) in enumerate(zip(title, name, album), 1):
    str += f'{i}위: {t.text.strip()} : {n.text.strip()} / 앨범: {a.text.strip()}\n'

print(str)
# Out:
# 1위: BANG BANG : IVE (아이브) / 앨범: REVIVE+
# 2위: 404 (New Era) : KiiiKiii (키키) / 앨범: Delulu Pack
# 3위: Good Goodbye : 화사 (HWASA) / 앨범: Good Goodbye
# 4위: 그대 작은 나의 세상이 되어 : 카더가든 / 앨범: 부재
# 5위: 사랑하게 될 거야 : 한로로 / 앨범: 이상비행
# 6위: Drowning : WOODZ / 앨범: OO-LI
# 7위: 타임캡슐 : 다비치 / 앨범: 타임캡슐
# 8위: 0+0 : 한로로 / 앨범: 자몽살구클럽
# 9위: Blue Valentine : NMIXX / 앨범: Blue Valentine
# 10위: Golden : HUNTR/X, EJAE, AUDREY NUNA, REI AMI, KPop Demon Hunters Cast / 앨범: KPop Demon Hunters (Soundtrack from the Netflix Film)
# 11위: 멸종위기사랑 : 이찬혁 / 앨범: EROS
# 12위: ONE MORE TIME : ALLDAY PROJECT / 앨범: ALLDAY PROJECT
# 13위: 어제보다 슬픈 오늘 : 우디 (Woody) / 앨범: 어제보다 슬픈 오늘
# 14위: SPAGHETTI (feat. j-hope of BTS) : LE SSERAFIM (르세라핌), j-hope / 앨범: SPAGHETTI
# 15위: 뛰어(JUMP) : BLACKPINK / 앨범: 뛰어(JUMP)
# 16위: BLACKHOLE : IVE (아이브) / 앨범: REVIVE+
# 17위: NOT CUTE ANYMORE : 아일릿(ILLIT) / 앨범: NOT CUTE ANYMORE
# 18위: RUDE! : Hearts2Hearts (하츠투하츠) / 앨범: RUDE!
# 19위: toxic till the end : 로제 (ROSÉ) / 앨범: rosie
# 20위: 모르시나요(PROD.로코베리) : 조째즈 / 앨범: 모르시나요
# 21위: 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 : AKMU (악뮤) / 앨범: 항해
# 22위: 너의 모든 순간 : 성시경 / 앨범: 별에서 온 그대 OST Part.7
# 23위: 달리 표현할 수 없어요 : 로이킴 / 앨범: 달리 표현할 수 없어요
# 24위: like JENNIE : 제니 (JENNIE) / 앨범: Ruby
# 25위: 내게 사랑이 뭐냐고 물어본다면 : 로이킴 / 앨범: 내게 사랑이 뭐냐고 물어본다면
# 26위: 사랑은 봄비처럼...이별은 겨울비처럼... : 임현정 / 앨범: All That Love
# 27위: FOCUS : Hearts2Hearts (하츠투하츠) / 앨범: FOCUS - The 1st Mini Album
# 28위: 천상연 : 이창섭 / 앨범: 천상연 (웹툰 '선녀외전' X 이창섭 (LEE CHANGSUB))
# 29위: HOME SWEET HOME (feat. 태양, 대성) : G-DRAGON / 앨범: HOME SWEET HOME (feat. 태양, 대성)
# 30위: FAMOUS : ALLDAY PROJECT / 앨범: FAMOUS
# 31위: REBEL HEART : IVE (아이브) / 앨범: IVE EMPATHY
# 32위: OVERDRIVE : TWS (투어스) / 앨범: TWS 4th Mini Album ‘play hard’
# 33위: Whiplash : aespa / 앨범: Whiplash - The 5th Mini Album
# 34위: 너에게 닿기를 : 10CM / 앨범: 너에게 닿기를
# 35위: 하얀 그리움 : 프로미스나인 / 앨범: 하얀 그리움
# 36위: Love Love Love (Feat. Yoong Jin Of Casker) : 에픽하이 (EPIK HIGH) / 앨범: Remapping The Human Soul
# 37위: 사랑은 늘 도망가 : 임영웅 / 앨범: 신사와 아가씨 OST Part.2
# 38위: 모든 날, 모든 순간 (Every day, Every Moment) : 폴킴 / 앨범: '키스 먼저 할까요?' OST Part.3
# 39위: STYLE : Hearts2Hearts (하츠투하츠) / 앨범: STYLE
# 40위: 나는 반딧불 : 황가람 / 앨범: 나는 반딧불
# 41위: 힙합보단 사랑, 사랑보단 돈 (Feat. 베이식) : 노아주다 (noahjooda) / 앨범: M O T N O A H
# 42위: 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) : 너드커넥션 (Nerd Connection) / 앨범: 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
# 43위: 시작의 아이 ❍ : 박다혜, 마크툽 (MAKTUB) / 앨범: 시작의 아이 ❍ ハジマリのコ Starting With You : ♡
# 44위: HAPPY : DAY6 (데이식스) / 앨범: Fourever
# 45위: 청춘만화 : 이무진 / 앨범: 만화 (滿花)
# 46위: XOXZ : IVE (아이브) / 앨범: IVE SECRET
# 47위: 소나기 : 이클립스 (ECLIPSE) / 앨범: 선재 업고 튀어 OST Part 1
# 48위: 오늘만 I LOVE YOU : BOYNEXTDOOR / 앨범: 오늘만 I LOVE YOU
# 49위: Soda Pop : KPop Demon Hunters Cast, Danny Chung, Saja Boys, Andrew Choi, Neckwav, Kevin Woo, samUIL Lee / 앨범: KPop Demon Hunters (Soundtrack from the Netflix Film)
# 50위: 예뻤어 : DAY6 (데이식스) / 앨범: Every DAY6 February
# 51위: 한 페이지가 될 수 있게 : DAY6 (데이식스) / 앨범: The Book of Us : Gravity
# 52위: 첫 만남은 계획대로 되지 않아 : TWS (투어스) / 앨범: TWS 1st Mini Album ‘Sparkling Blue’
# 53위: APT. : 로제 (ROSÉ), Bruno Mars / 앨범: APT.
# 54위: 주저하는 연인들을 위해 : 잔나비 / 앨범: 전설
# 55위: I AM : IVE (아이브) / 앨범: I've IVE
# 56위: Flower : 오반(OVAN) / 앨범: 교회오빠
# 57위: Love wins all : 아이유 / 앨범: The Winning
# 58위: 눈사람 : 정승환 / 앨범: 그리고 봄
# 59위: Welcome to the Show : DAY6 (데이식스) / 앨범: Fourever
# 60위: 시작의 아이 : 마크툽 (MAKTUB) / 앨범: 시작의 아이 ハジマリのコ (Starting With You)
# 61위: 사랑인가 봐 : 멜로망스 / 앨범: 사랑인가 봐 (사내맞선 OST 스페셜 트랙)
# 62위: 사랑의 언어 (Love Language) : 김민석 (멜로망스) / 앨범: 이 사랑 통역 되나요? (Soundtrack from the Netflix Series)
# 63위: Zoo (From "Zootopia 2"/Soundtrack Version) : Disney, Shakira / 앨범: Zoo (From "Zootopia 2")
# 64위: Die With A Smile : Lady Gaga, Bruno Mars / 앨범: Die With A Smile
# 65위: 그래 늦지 않았어 (2025) : 아샤트리, 이예은, 전건호 / 앨범: 그래 늦지 않았어(2025)
# 66위: 순간을 영원처럼 : 임영웅 / 앨범: IM HERO 2
# 67위: 청혼하지 않을 이유를 못 찾았어 : 이무진 / 앨범: 청혼하지 않을 이유를 못 찾았어
# 68위: 우리들의 블루스 : 임영웅 / 앨범: IM HERO
# 69위: Never Ending Story : 아이유 / 앨범: 꽃갈피 셋
# 70위: 다정히 내 이름을 부르면 : 경서예지, 전건호 / 앨범: 다정히 내 이름을 부르면 (경서예지 x 전건호)
# 71위: 한번 더 이별 : 이창섭 / 앨범: 한번 더 이별 (첫사랑 엔딩 X 이창섭)
# 72위: 끝사랑 : 테이 / 앨범: 끝사랑
# 73위: TOO BAD (feat. Anderson .Paak) : G-DRAGON / 앨범: Übermensch
# 74위: 운명 (2025) : 먼데이 키즈, 이이경 / 앨범: 먼키의 발자국 Vol.1 With 이이경
# 75위: Magnetic : 아일릿(ILLIT) / 앨범: SUPER REAL ME
# 76위: Rich Man : aespa / 앨범: Rich Man - The 6th Mini Album
# 77위: IRIS OUT : Kenshi Yonezu / 앨범: IRIS OUT
# 78위: 헤어지자 말해요 : 박재정 / 앨범: 1집 Alone
# 79위: 인사 : 범진 / 앨범: 인사
# 80위: Seven (feat. Latto) - Clean Ver. : 정국 / 앨범: Seven (feat. Latto) - Clean Ver.
# 81위: 다시 만날 수 있을까 : 임영웅 / 앨범: IM HERO
# 82위: Daydream : 웬디 (WENDY) / 앨범: 이 사랑 통역 되나요? (Soundtrack from the Netflix Series)
# 83위: 365일 : 이창섭 / 앨범: 365일 (오늘 밤, 세계에서 이 사랑이 사라진다 해도 X 이창섭)
# 84위: Hype Boy : NewJeans / 앨범: NewJeans 1st EP 'New Jeans'
# 85위: 비의 랩소디 : 임재현 / 앨범: 비의 랩소디
# 86위: 눈이 오잖아(Feat.헤이즈) : 이무진 / 앨범: 눈이 오잖아(Feat.헤이즈)
# 87위: MY LOVE(2025) : 이예은, 아샤트리, 전건호 / 앨범: MY LOVE(2025)
# 88위: Supernova : aespa / 앨범: Armageddon - The 1st Album
# 89위: 에피소드 : 이무진 / 앨범: 에피소드
# 90위: 빌려온 고양이 (Do the Dance) : 아일릿(ILLIT) / 앨범: bomb
# 91위: Hollywood Action : BOYNEXTDOOR / 앨범: The Action
# 92위: 다시 만난 오늘 : TWS (투어스) / 앨범: 다시 만난 오늘
# 93위: 첫 눈 : EXO / 앨범: 겨울 스페셜 앨범 '12월의 기적 (Miracles In December)'
# 94위: Dirty Work : aespa / 앨범: Dirty Work
# 95위: 이 밤을 빌려 말해요 : PLAVE / 앨범: 이 밤을 빌려 말해요 (오늘 밤, 세계에서 이 사랑이 사라진다 해도 X PLAVE)
# 96위: 들꽃이 될게요 : 임영웅 / 앨범: IM HERO 2
# 97위: 슬픈 초대장 : 순순희(지환) / 앨범: 슬픈 초대장
# 98위: 고민중독 : QWER / 앨범: 1st Mini Album 'MANITO'
# 99위: 가만히 눈을 감고 : DK(디셈버) / 앨범: 가만히 눈을 감고
# 100위: 그댈 위한 멜로디 : 임영웅 / 앨범: IM HERO 2

# %%
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.pusan.ac.kr/kor/CMS/MenuMgr/menuListOnBuilding.do?mCode=MN202"
headers = {"user-agent":"Mozilla/5.0 (Window NT 10.0: Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0"}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html.parser')
menulist = soup.select('.menu-tbl')
menu = soup.select('h3.menu-tit01 + p')
won = soup.select('.menu-tit01')
day = soup.select('.day')
date = soup.select('.date')
for d, dd, w, m in zip(day, date, won, menu):
    print('=' * 15)
    print(d.text.strip(), dd.text.strip())
    print('-' * 15)
    print(w.text + '\n' + m.text.replace('\r', '\n'))
# Out:
# ===============
# 월 2026.02.23
# ---------------
# 정식-5,500원
# 백미밥
# 반계탕
# 탕수육/레몬소스
# 사각어묵오징어무침
# 잔멸치건새우견과류볶음
# 다시마무채무침
# 포기김치
#
# ===============
# 화 2026.02.24
# ---------------
# 정식-5,500원
# 녹차밥
# 수제비국
# 돈육김치볶음
# 새우가스/케찹
# 푸실리과일샐러드
# 상추겉절이
# 석박지
#
# ===============
# 수 2026.02.25
# ---------------
# 정식-5,500원
# 백미밥
# 짬뽕국
# 떡갈비/파채소스
# 스파게티/로제소스
# 어묵버섯조림
# 치커리유자청무침
# 배추김치
#
# ===============
# 목 2026.02.26
# ---------------
# 정식-5,500원
# 흑미밥
# 어묵국
# 치킨치즈가스/머스터드
# 쇠고기하이라이스
# 순대볶음
# 해초무초무침
# 배추김치
#
# ===============
# 금 2026.02.27
# ---------------
# 정식-5,500원
# 백미밥
# 닭개장
# 돈육바삭불고기
# 우동야채볶음
# 볶음김치/온두부
# 콩나물무침
# 석박지

# %%
# !pip install -q -U google-genai

# %%
# 구글 제미나이 AI
import os
from google import genai
os.environ["GEMINI_API_KEY"] =

api_key = os.environ["GEMINI_API_KEY"]

client = genai.Client(api_key=api_key) 

contents = input("질문:")
response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents=contents,
)
print(response.text)
# Out:
# 질문: 원탁의 기사가 구조가 어떻게 돼?
# 원탁의 기사는 아서 왕의 전설 속 유명한 이야기이며, 여러 버전의 이야기가 존재하여 구조가 조금씩 다를 수 있습니다. 하지만 보편적으로 나타나는 주요 구조와 특징은 다음과 같습니다.
#
# **1. 주인공의 등장과 성장:**
#
# *   **아서 왕의 즉위:** 이야기는 보통 평범한 소년이었던 아서가 엑스칼리버를 뽑거나 신의 계시를 받아 왕위에 오르는 것으로 시작합니다. 이는 그의 타고난 운명과 왕으로서의 정통성을 보여줍니다.
# *   **마법사 멀린의 역할:** 아서의 멘토이자 조력자인 멀린은 그의 성장에 중요한 역할을 합니다. 멀린은 아서에게 지혜와 조언을 제공하며, 그의 왕국을 건설하는 데 도움을 줍니다.
# *   **원탁의 건설:** 아서 왕은 자신의 신념과 이상을 실현하기 위해 원탁을 세웁니다. 이는 계급이나 지위의 차별 없이 모든 기사가 동등하게 앉아 논의하고 협력하는 상징적인 장소입니다.
#
# **2. 황금기:**
#
# *   **이상적인 왕국:** 원탁의 기사들이 모여 정의롭고 평화로운 왕국을 건설합니다. 이 시기에는 기사들이 용감하게 악을 물리치고 약자를 돕는 활약이 묘사됩니다.
# *   **기사들의 맹세와 이상:** 기사들은 각자 고결한 덕목(용기, 충성, 명예, 정의, 자비 등)을 지키며, 이를 바탕으로 세상의 질서를 바로잡으려는 노력을 합니다.
# *   **성배 탐색:** 원탁의 기사 이야기의 백미 중 하나는 성배 탐색입니다. 순수한 마음을 가진 기사만이 찾을 수 있다고 여겨지는 성배는 영적인 완성과 구원을 상징하며, 기사들의 신앙심과 덕목을 시험하는 중요한 사건입니다.
#
# **3. 갈등과 몰락:**
#
# *   **내부 분열:** 이야기가 진행되면서 원탁 내부의 갈등이 발생합니다. 이는 기사들 간의 질투, 배신, 오해, 혹은 인간적인 욕망 때문일 수 있습니다.
# *   **아서 왕의 인간적인 고뇌:** 아서 왕 역시 완벽한 인물이 아니며, 그의 결정이나 실수, 혹은 인간적인 나약함이 몰락을 야기하기도 합니다.
# *   **배신과 파멸:** 기사들의 배신, 특히 가장 가까웠던 인물(예: 랜슬롯과 귀네비어의 관계, 모드레드의 배신)은 원탁의 균열을 결정적으로 만듭니다.
# *   **카멜롯의 멸망:** 결국 이러한 갈등과 배신은 카멜롯의 멸망으로 이어지며, 아서 왕은 최후의 전투를 치르게 됩니다.
#
# **4. 결말:**
#
# *   **아서 왕의 죽음 (혹은 잠복):** 아서 왕은 마지막 전투에서 치명상을 입고 죽거나, 혹은 '아발론'이라는 신비로운 섬으로 옮겨져 언젠가 다시 돌아올 때까지 잠들어 있다는 이야기가 있습니다.
# *   **원탁의 흩어짐:** 원탁의 기사들은 각자의 운명에 따라 흩어지거나 죽음을 맞이하며, 이상적인 시대는 막을 내립니다.
# *   **교훈과 전설:** 그럼에도 불구하고 원탁의 기사 이야기는 정의, 용기, 명예 등 인간적인 가치를 강조하며 후대에까지 큰 영향을 미치는 전설로 남습니다.
#
# **핵심 구조 요소:**
#
# *   **영웅 서사시:** 주인공의 탄생, 성장, 시련, 성공, 몰락의 과정을 담고 있습니다.
# *   **이상과 현실의 대비:** 기사들의 고결한 이상과 인간적인 욕망, 현실적인 갈등이 충돌합니다.
# *   **도덕적 교훈:** 정의, 충성, 명예 등 덕목의 중요성을 강조하며, 인간의 나약함과 죄악이 초래하는 파멸을 보여줍니다.
# *   **상징주의:** 원탁, 엑스칼리버, 성배 등은 강력한 상징성을 지니고 있습니다.
#
# 간단히 말해, 원탁의 기사 이야기는 **이상적인 왕국을 건설하려는 영웅의 노력, 그 안에서 발생하는 인간적인 갈등과 죄악, 그리고 결국 몰락하지만 그 정신은 전설로 남는다는 구조**를 가지고 있다고 할 수 있습니다.
